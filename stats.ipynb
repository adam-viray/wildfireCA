# %%
import pstats
from pstats import SortKey

# %%
p = pstats.Stats('CAprofile_250m')
p

# %%
p.sort_stats('filename','tottime')
p.print_stats()
# Out:
# Wed Aug 30 12:32:19 2023    CAprofile_250m
#
#          428021 function calls (414937 primitive calls) in 2.571 seconds
#
#    Ordered by: file name, internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.014    0.003    0.020    0.004 /home/adam.viray/Documents/CA/code/CA_riceridge.py:168(get_adj_dw)
#         1    0.003    0.003    2.571    2.571 /home/adam.viray/Documents/CA/code/CA_riceridge.py:254(run)
#         2    0.002    0.001    2.541    1.271 /home/adam.viray/Documents/CA/code/CA_riceridge.py:134(plot)
#        44    0.001    0.000    0.022    0.000 /home/adam.viray/Documents/CA/code/CA_riceridge.py:227(ignite)
#        44    0.001    0.000    0.001    0.000 /home/adam.viray/Documents/CA/code/CA_riceridge.py:194(spread)
#        44    0.001    0.000    0.001    0.000 /home/adam.viray/Documents/CA/code/CA_riceridge.py:161(step_size)
# ...
